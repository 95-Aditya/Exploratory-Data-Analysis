# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Below data is made by taking new york city as base(with 100%) as new york is one of the expensive city in world.
# In below data if there is any value of 109.56, it indicates that it is 9.56% more when compared to new york city index.

# %%
e2=pd.read_csv("Cost_of_Living_Index_by_Country_2024.csv")
e2
# Out:
#      Rank      Country  Cost of Living Index  Rent Index  \
# 0       1  Switzerland                 101.1        46.5
# 1       2      Bahamas                  85.0        36.7
# 2       3      Iceland                  83.0        39.2
# 3       4    Singapore                  76.7        67.2
# 4       5     Barbados                  76.6        19.0
# ..    ...          ...                   ...         ...
# 116   117   Bangladesh                  22.5         2.4
# 117   118        India                  21.2         5.6
# 118   119        Egypt                  21.0         3.7
# 119   120        Libya                  20.4         4.3
# 120   121     Pakistan                  18.8         2.8
#
#      Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                              74.9            109.1                    97.0
# 1                              61.8             81.6                    83.3
# ...

# %%
e2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank                            121 non-null    int64
#  1   Country                         121 non-null    object
#  2   Cost of Living Index            121 non-null    float64
#  3   Rent Index                      121 non-null    float64
#  4   Cost of Living Plus Rent Index  121 non-null    float64
#  5   Groceries Index                 121 non-null    float64
#  6   Restaurant Price Index          121 non-null    float64
#  7   Local Purchasing Power Index    121 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 7.7+ KB

# %%
e2.describe()
# Out:
#              Rank  Cost of Living Index  Rent Index  \
# count  121.000000            121.000000  121.000000
# mean    61.000000             43.555372   16.052893
# std     35.073732             16.147574   11.412267
# min      1.000000             18.800000    2.400000
# 25%     31.000000             30.200000    8.500000
# 50%     61.000000             39.500000   12.400000
# 75%     91.000000             52.800000   20.100000
# max    121.000000            101.100000   67.200000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      121.000000       121.000000
# mean                        30.357851        44.228926
# std                         13.263721        17.055109
# min                         11.100000        17.500000
# 25%                         19.800000        31.600000
# 50%                         27.000000        40.500000
# 75%                         37.000000        53.700000
# ...

# %%
e2.dtypes

# %%
e2.head(20)

# %%
e2.tail(20)

# %%
plt.bar(e2["Country"].loc[:20],e2["Local Purchasing Power Index"].loc[:20],color=(e2["Local Purchasing Power Index"].loc[:20]>100.0).map({True:"red",False:"green"}),width=0.8)
plt.gcf().set_size_inches(14,7)
plt.xlabel("Countries")
plt.ylabel("Local Purchasing Power Index")
plt.xticks(rotation=90)
plt.title("Top 20 Countries")
plt.show()

# %% [markdown]
# Local Purchasing Power: This index indicates the relative purchasing power in a given city based on the average net salary. A domestic purchasing power of 40 means that residents with an average salary can afford, on average, 60% less goods and services compared to residents of New York City with an average salary.
#
# By above graph(for top 20 countries), Luxembory is having highest Local Purchasing Power Index.This means the residents of luxemborg with an average salary need to afford 82.5% more on goods and services when compared to New York city residents.
#
# Bahamas,Barbodas are having lowest Local Purchasing Power Index in top 20 countries.

# %%
plt.bar(e2["Country"].loc[101:120],e2["Local Purchasing Power Index"].loc[101:120])
plt.title("Bottom 20 Countries")
plt.gcf().set_size_inches(14,7)
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar(e2["Country"].loc[:20],e2["Cost of Living Index"].loc[:20],color='#E4080A',label="Cost of Living Index")
plt.bar(e2["Country"].loc[:20],e2["Cost of Living Plus Rent Index"].loc[:20],color='#DFC57B',label="Cost of Living Plus Rent Index")
plt.xticks(rotation=90)
plt.gcf().set_size_inches(14,7)
plt.legend()
plt.show()

# %% [markdown]
# Cost of Living Index (Excl. Rent): This index indicates the relative prices of consumer goods like groceries, restaurants, transportation, and utilities. It excludes accommodation expenses such as rent or mortgage. For instance, a city with a Cost of Living Index of 120 is estimated to be 20% more expensive than New York City (excluding rent).
# Cost of Living Index is less in most of the countries except for switzerland which is having more than 1.1% more compared to New york city.
#
# Cost of Living Plus Rent Index: This index estimates consumer goods prices, including rent, in comparison to New York City.
# Cost of Living Plus Rent Index in the Top 20 countries are low when compared to new york city.

# %%
lp=e2[e2["Local Purchasing Power Index"] > 100]

# %%
lp
# Out:
#     Rank               Country  Cost of Living Index  Rent Index  \
# 0      1           Switzerland                 101.1        46.5
# 2      3               Iceland                  83.0        39.2
# 3      4             Singapore                  76.7        67.2
# 5      6                Norway                  76.0        26.2
# 6      7               Denmark                  72.3        26.4
# 7      8     Hong Kong (China)                  70.8        59.4
# 8      9         United States                  70.4        41.7
# 9     10             Australia                  70.2        33.4
# 10    11               Austria                  65.1        22.5
# 11    12                Canada                  64.8        33.2
# 12    13           New Zealand                  64.6        25.9
# 13    14               Ireland                  64.4        42.3
# 14    15                France                  63.7        21.0
# ...

# %%
plt.bar(lp["Country"],lp["Local Purchasing Power Index"],color="#D95A5C")
plt.gcf().set_size_inches(14,7)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The above bar graph shows the local purchase power index of countries greater than 100.
# Overall Switzerland is having highest cost of living index when compared to other countries, but there are some other index parameters like local purchase power index where switzerland is lagging behind Luxembourg and kuwait.
